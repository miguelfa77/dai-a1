# %% [markdown]
# ### Import data (question, answer)

# %%
import pandas as pd
import numpy as np

INPUT_FILE_PATH = "Q&A_db_practice.json"

df = pd.read_json(INPUT_FILE_PATH)

# %%
df
# Out:
#                             question  \
# 0                Activation Function
# 1                  Anomaly Detection
# 2         Area Under the Curve (AUC)
# 3            Artificial Intelligence
# 4    Artificial Neural Network (ANN)
# ..                               ...
# 145                Unstructured Data
# 146            Unsupervised Learning
# 147               Vanishing Gradient
# 148                         Variance
# 149          Variational Autoencoder
#
#                                                 answer
# 0    An activation function is a mathematical funct...
# 1    Anomaly detection is a subfield of unsupervise...
# 2    The Area Under the Curve (AUC) is a scalar per...
# 3    Artificial intelligence is a subfield that des...
# 4    An artificial neural network (ANN) is a comput...
# ..                                                 ...
# 145  Unstructured data is any data that does not co...
# 146  Unsupervised learning is a class of algorithms...
# 147  Vanishing gradient is a training pathology tha...
# 148  Variance is a statistical measure that quantif...
# 149  A Variational Autoencoder is a generative neur...
#
# [150 rows x 2 columns]

# %% [markdown]
# ### Establish question and answer

# %%
import random

question = random.choice(df["question"])
ref_answer = random.choice(df["answer"])

# %%
student_answer = str(input(f"{question}: "))

# %% [markdown]
# ### Evaluator

# %%
prompt = f"""
You are an expert ML examiner.

Question: {question}
Reference answer: {ref_answer}
Student answer: {student_answer}

Evaluate the student's answer for correctness, completeness, and precision.
Explain briefly what is missing or incorrect.
Then provide a numer
Score: <number>
Feedback: <short explanation>
"""

# %%
from google import genai


client = genai.Client(api_key="<API_KEY>")

def evaluate_answer(question, ref_answer, student_answer, model="gemini-2.5-flash-lite"):
    """Calls the GenAI evaluator model and returns the raw text response."""
    prompt = f"""
        You are an expert ML examiner.

        Question: {question}
        Reference answer: {ref_answer}
        Student answer: {student_answer}

        First step is figure out if 'Student answer' is an attempt at responding the 'Question'.
        - If it is not: Then respond like in a normal conversation.
        - If it is: Then do the following.
        Evaluate the student's answer for correctness, completeness, and precision.
        Explain briefly what is missing or incorrect.
        Then provide a numeric score from 0 to 100 (using the Reference answer as a reference) in the format:
        Score: <number> n\
        Feedback: <short explanation>
        """
    # Call the GenAI model
    response = client.models.generate_content(
        model=model,
        contents=prompt,
    )
    return response.text
# Out:
# The student's answer correctly identifies the core problem of vanishing gradients in deep learning models, particularly RNNs. They accurately describe the effect on weight updates: becoming smaller and smaller, leading to very slow or stalled learning. The mention of "almost logarithmic" is an intuitive but not mathematically precise description of the decay.
#
# What's missing for a more complete and precise answer is:
# 1.  **The cause of vanishing gradients:** While they mention the effect, they don't explain *why* it happens. This is typically due to the repeated multiplication of small gradients (often less than 1) during backpropagation, especially in deep networks or recurrent connections. Activation functions like sigmoid or tanh, when their inputs are saturated, also contribute significantly by having very small derivatives.
# 2.  **The consequences:** Beyond slow learning, vanishing gradients can lead to the earlier layers of a network learning very little, effectively making the network unable to capture complex, long-range dependencies (especially relevant for RNNs).
# 3.  **Mention of Exploding Gradients:** Vanishing gradients are often discussed alongside their opposite, exploding gradients, which is also a common problem in deep learning training.
#
# Score: 75
# Feedback: The answer correctly describes the effect of vanishing gradients on weight updates and identifies the relevant models (deep learning, RNNs). However, it lacks an explanation of the underlying causes and the full implications of the problem.

# %% [markdown]
# ### ROUGE-L implementation

# %%
import evaluate 

rouge = evaluate.load("rouge")

results = rouge.compute(predictions=['Hello'], references=['Helli'], rouge_type=["rougeL"], use_stemmer=True)

float(result["rougeL"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import evaluate
#       3 rouge = evaluate.load("rouge")
#       5 results = rouge.compute(predictions=['Hello'], references=['Helli'], rouge_type=["rougeL"], use_stemmer=True)
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/evaluate/__init__.py:29
#      25 SCRIPTS_VERSION = "main" if version.parse(__version__).is_devrelease else __version__
#      27 del version
# ---> 29 from .evaluation_suite import EvaluationSuite
#      30 from .evaluator import (
#      31     AudioClassificationEvaluator,
#      32     AutomaticSpeechRecognitionEvaluator,
#    (...)
#      42     evaluator,
#      43 )
#      44 from .hub import push_to_hub
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/evaluate/evaluation_suite/__init__.py:7
#       4 from pathlib import Path
#       5 from typing import Callable, Dict, Optional, Union
# ----> 7 from datasets import Dataset, DownloadConfig, DownloadMode, load_dataset
#       8 from datasets.utils.version import Version
#      10 from ..evaluator import evaluator
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/datasets/__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "4.4.1"
# ---> 17 from .arrow_dataset import Column, Dataset
#      18 from .arrow_reader import ReadInstruction
#      19 from .builder import ArrowBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/datasets/arrow_dataset.py:104
#      91 from .filesystems import is_remote_filesystem
#      92 from .fingerprint import (
#      93     fingerprint_transform,
#      94     format_kwargs_for_fingerprint,
#    (...)
#     102     validate_fingerprint,
#     103 )
# --> 104 from .formatting import format_table, get_format_type_from_alias, get_formatter, query_table
#     105 from .formatting.formatting import LazyDict, _is_range_contiguous
#     106 from .info import DatasetInfo, DatasetInfosDict
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/datasets/formatting/__init__.py:91
#      88     _register_unavailable_formatter(_polars_error, "polars", aliases=["pl"])
#      90 if config.TORCH_AVAILABLE:
# ---> 91     from .torch_formatter import TorchFormatter
#      93     _register_formatter(TorchFormatter, "torch", aliases=["pt", "pytorch"])
#      94 else:
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/datasets/formatting/torch_formatter.py:32
#      30 # Import torch once at module level once
#      31 try:
# ---> 32     import torch
#      34     _torch_available = True
#      35 except ImportError:
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/torch/__init__.py:1539
#    1532 from ._compile import _disable_dynamo
#    1534 ################################################################################
#    1535 # Import interface functions defined in Python
#    1536 ################################################################################
#    1537
#    1538 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 1539 from .functional import *  # noqa: F403
#    1542 ################################################################################
#    1543 # Remove unnecessary members
#    1544 ################################################################################
#    1546 del _StorageBase
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/torch/functional.py:9
#       7 import torch
#       8 from torch._C import _add_docstr
# ----> 9 import torch.nn.functional as F
#      10 from ._lowrank import svd_lowrank, pca_lowrank
#      11 from .overrides import (
#      12     has_torch_function, has_torch_function_unary, has_torch_function_variadic,
#      13     handle_torch_function)
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/torch/nn/__init__.py:1
# ----> 1 from .modules import *  # noqa: F403
#       2 from .parameter import (
#       3     Parameter as Parameter,
#       4     UninitializedParameter as UninitializedParameter,
#       5     UninitializedBuffer as UninitializedBuffer,
#       6 )
#       7 from .parallel import DataParallel as DataParallel
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/torch/nn/modules/__init__.py:1
# ----> 1 from .module import Module
#       2 from .linear import Identity, Linear, Bilinear, LazyLinear
#       3 from .conv import Conv1d, Conv2d, Conv3d, \
#       4     ConvTranspose1d, ConvTranspose2d, ConvTranspose3d, \
#       5     LazyConv1d, LazyConv2d, LazyConv3d, LazyConvTranspose1d, LazyConvTranspose2d, LazyConvTranspose3d
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:879, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:975, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1074, in get_data(self, path)
#
# KeyboardInterrupt:
