# %% [markdown]
# # Part 1 - NetworkX

# %% [markdown]
# ### Download libraries

# %%
import pandas as pd
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'dai-a1 (Python 3.10.8)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Read data

# %%
#df_csv = pd.read_csv('teachers_db_practice.csv')
df_parquet = pd.read_parquet('teachers_db_practice.parquet', engine='pyarrow')

# %%
df_parquet
# Out:
#                                             area  area_code  \
# 0                          Architecture & Design      40358
# 1                                      Economics      17166
# 2                         Private & Business Law      40353
# 3                                      Economics      17166
# 4                           Science & Technology      40359
# ...                                          ...        ...
# 1223            Information Systems & Technology      29474
# 1224  Economics+Strategy+International Relations      17166
# 1225                                     Finance      29472
# 1226                       Architecture & Design      40358
# 1227                       Architecture & Design      40358
#
#                position                                          full_info  \
# 0                  None  <p>  has worked as a designer for the last dec...
# 1                  None  <p>Mr.  Madgar has been teaching economics par...
# ...

# %% [markdown]
# ### Import model from huggingface: dslim/bert-base-NER

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# %%
import os
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"

# %%
# !pip3 uninstall -y torch torchvision torchaudio triton
# Out:
# ^C

# %%
tokenizer = AutoTokenizer.from_pretrained('dslim/bert-base-NER')
model = AutoModelForTokenClassification.from_pretrained('dslim/bert-base-NER')
#ner_model = pipeline(task='image-classification', model='dslim/bert-base-NER', aggregation_strategy='simple', device=1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 2
#       1 tokenizer = AutoTokenizer.from_pretrained('dslim/bert-base-NER')
# ----> 2 model = AutoModelForTokenClassification.from_pretrained('dslim/bert-base-NER')
#       3 #ner_model = pipeline(task='image-classification', model='dslim/bert-base-NER', aggregation_strategy='simple', device=1)
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/transformers/utils/import_utils.py:2157, in DummyObject.__getattribute__(cls, key)
#    2155 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2156     return super().__getattribute__(key)
# -> 2157 requires_backends(cls, cls._backends)
#
# File ~/Desktop/DAI-A1-INSTRUCTIONS/dai-a1/lib/python3.10/site-packages/transformers/utils/import_utils.py:2143, in requires_backends(obj, backends)
# ...

# %%
df_parquet['entities']
